# %% [markdown]
# <h1> FPL 2021/22 Season, working with Forwards </h1>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("FWD_2021-22.csv")
df.head()
# Out:
#                      name position         team   xP  assists  bonus  bps  \
# 0            Keinan Davis      FWD  Aston Villa  0.4        0      0    0
# 1             Joshua King      FWD      Watford  0.0        0      0    0
# 2  Richarlison de Andrade      FWD      Everton  2.4        1      3   41
# 3           Armando Broja      FWD  Southampton  1.3        0      0    0
# 4            Stipe Perica      FWD      Watford  0.5        0      0    0
#
#    clean_sheets  creativity  element  ...  team_h_score  threat  total_points  \
# 0             0         0.0       49  ...             3       0             0
# 1             0         0.0      468  ...             3       0             0
# 2             0        29.3      180  ...             3      37            11
# 3             0         0.0      518  ...             3       0             0
# 4             0         0.0      388  ...             3       0             0
#
# ...

# %%
df.columns
# Out:
# Index(['name', 'position', 'team', 'xP', 'assists', 'bonus', 'bps',
#        'clean_sheets', 'creativity', 'element', 'fixture', 'goals_conceded',
#        'goals_scored', 'ict_index', 'influence', 'kickoff_time', 'minutes',
#        'opponent_team', 'own_goals', 'penalties_missed', 'penalties_saved',
#        'red_cards', 'round', 'saves', 'selected', 'team_a_score',
#        'team_h_score', 'threat', 'total_points', 'transfers_balance',
#        'transfers_in', 'transfers_out', 'value', 'was_home', 'yellow_cards',
#        'GW'],
#       dtype='object')

# %%
df= df[df['minutes'] > 0 ]

# %%
print(df.size)
# Out:
# 50508

# %%
forward_features = ['name', 'team','opponent_team', 'xP', 'creativity', 'element', 'ict_index', 'influence', 'kickoff_time', 'threat',  'value', 'was_home']

# %%
df_FWD = df[forward_features]

# %%
df_FWD
# Out:
#                                name            team  opponent_team   xP  \
# 2            Richarlison de Andrade         Everton             16  2.4
# 8                      Raúl Jiménez          Wolves              9  1.9
# 9                   Emmanuel Dennis         Watford              2  0.8
# 11                        Che Adams     Southampton              8  2.2
# 14             Jean-Philippe Mateta  Crystal Palace              6  1.1
# ...                             ...             ...            ...  ...
# 3383  João Pedro Junqueira de Jesus         Watford              6  1.2
# 3384                    Neal Maupay        Brighton             19  0.6
# 3385                  Danny Welbeck        Brighton             19  8.2
# 3389                Michail Antonio        West Ham              4  3.6
# 3391   Juan Camilo Hernández Suárez         Watford              6 -0.6
#
#       creativity  element  ict_index  influence          kickoff_time  threat  \
# ...

# %%
df_FWD.loc[:, 'time'] = pd.to_datetime(df_FWD['kickoff_time']).dt.strftime('%H:%M')
# Out:
# C:\Users\salee\AppData\Local\Temp\ipykernel_31544\40025024.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_FWD.loc[:, 'time'] = pd.to_datetime(df_FWD['kickoff_time']).dt.strftime('%H:%M')

# %%
df_FWD
# Out:
#                                name            team  opponent_team   xP  \
# 2            Richarlison de Andrade         Everton             16  2.4
# 8                      Raúl Jiménez          Wolves              9  1.9
# 9                   Emmanuel Dennis         Watford              2  0.8
# 11                        Che Adams     Southampton              8  2.2
# 14             Jean-Philippe Mateta  Crystal Palace              6  1.1
# ...                             ...             ...            ...  ...
# 3383  João Pedro Junqueira de Jesus         Watford              6  1.2
# 3384                    Neal Maupay        Brighton             19  0.6
# 3385                  Danny Welbeck        Brighton             19  8.2
# 3389                Michail Antonio        West Ham              4  3.6
# 3391   Juan Camilo Hernández Suárez         Watford              6 -0.6
#
#       creativity  element  ict_index  influence          kickoff_time  threat  \
# ...

# %%
df_FWD.shape
# Out:
# (1403, 13)

# %%
df_FWD = df_FWD.drop('kickoff_time', axis = 'columns')

# %%
df_FWD
# Out:
#                                name            team  opponent_team   xP  \
# 2            Richarlison de Andrade         Everton             16  2.4
# 8                      Raúl Jiménez          Wolves              9  1.9
# 9                   Emmanuel Dennis         Watford              2  0.8
# 11                        Che Adams     Southampton              8  2.2
# 14             Jean-Philippe Mateta  Crystal Palace              6  1.1
# ...                             ...             ...            ...  ...
# 3383  João Pedro Junqueira de Jesus         Watford              6  1.2
# 3384                    Neal Maupay        Brighton             19  0.6
# 3385                  Danny Welbeck        Brighton             19  8.2
# 3389                Michail Antonio        West Ham              4  3.6
# 3391   Juan Camilo Hernández Suárez         Watford              6 -0.6
#
#       creativity  element  ict_index  influence  threat  value  was_home  \
# ...
