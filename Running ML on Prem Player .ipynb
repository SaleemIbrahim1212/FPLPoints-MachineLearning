# %%
import pandas as pd

# %%
prem_player = pd.read_csv("PLALLEverySeason-noappearances.csv")
prem_player
# Out:
#        Unnamed: 0        Date  Day            Comp         Round Venue Result  \
# 0               3  2018-08-12  Sun  Premier League   Matchweek 1  Away  W 2–0
# 1               4  2018-08-19  Sun  Premier League   Matchweek 2  Home  W 6–1
# 2               5  2018-08-25  Sat  Premier League   Matchweek 3  Away  D 1–1
# 3               6  2018-09-01  Sat  Premier League   Matchweek 4  Home  W 2–1
# 4               7  2018-09-15  Sat  Premier League   Matchweek 5  Home  W 3–0
# ...           ...         ...  ...             ...           ...   ...    ...
# 54277          21  2023-05-28  Sun  Premier League  Matchweek 38  Home  D 4–4
# 54278          15  2023-05-21  Sun  Premier League  Matchweek 37  Away  L 1–3
# 54279          44  2023-01-21  Sat  Premier League  Matchweek 21  Home  L 0–1
# 54280          15  2023-05-28  Sun  Premier League  Matchweek 38  Home  D 4–4
# 54281           0  2022-08-06  Sat  Premier League   Matchweek 1  Away  L 1–4
#
# ...

# %%
prem_player.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'Day', 'Comp', 'Round', 'Venue', 'Result',
#        'Squad', 'Opponent', 'Start', 'Pos', 'Min', 'Gls', 'Ast', 'PK', 'PKatt',
#        'Sh', 'SoT', 'CrdY', 'CrdR', 'Touches', 'Tkl', 'Int', 'Blocks', 'xG',
#        'npxG', 'xAG', 'SCA', 'GCA', 'Cmp', 'Att', 'Cmp%', 'PrgP', 'Carries',
#        'PrgC', 'Att.1', 'Succ', 'Match Report', 'name', 'season'],
#       dtype='object')

# %%
prem_player = prem_player.drop(['Match Report', 'Unnamed: 0', 'Comp'], axis = 1 )

# %%
prem_player
# Out:
#              Date  Day         Round Venue Result            Squad  \
# 0      2018-08-12  Sun   Matchweek 1  Away  W 2–0  Manchester City
# 1      2018-08-19  Sun   Matchweek 2  Home  W 6–1  Manchester City
# 2      2018-08-25  Sat   Matchweek 3  Away  D 1–1  Manchester City
# 3      2018-09-01  Sat   Matchweek 4  Home  W 2–1  Manchester City
# 4      2018-09-15  Sat   Matchweek 5  Home  W 3–0  Manchester City
# ...           ...  ...           ...   ...    ...              ...
# 54277  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54278  2023-05-21  Sun  Matchweek 37  Away  L 1–3      Southampton
# 54279  2023-01-21  Sat  Matchweek 21  Home  L 0–1      Southampton
# 54280  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54281  2022-08-06  Sat   Matchweek 1  Away  L 1–4      Southampton
#
#             Opponent Start    Pos   Min  ...   Cmp   Att   Cmp%  PrgP  \
# 0            Arsenal     Y     GK  90.0  ...  33.0  46.0   71.7   0.0
# ...

# %%
prem_mutiple_pos = prem_player[prem_player['Pos'].str.len() > 2]

# %%
prem_mutiple_pos
# Out:
#              Date  Day         Round Venue Result            Squad  \
# 52     2018-12-04  Tue  Matchweek 15  Away  W 2–1  Manchester City
# 73     2018-08-12  Sun   Matchweek 1  Away  W 2–0  Manchester City
# 74     2018-08-19  Sun   Matchweek 2  Home  W 6–1  Manchester City
# 76     2018-09-01  Sat   Matchweek 4  Home  W 2–1  Manchester City
# 82     2018-10-29  Mon  Matchweek 10  Away  W 1–0  Manchester City
# ...           ...  ...           ...   ...    ...              ...
# 54224  2023-01-14  Sat  Matchweek 20  Away  W 2–1      Southampton
# 54229  2023-03-12  Sun  Matchweek 27  Away  D 0–0      Southampton
# 54249  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54275  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54277  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
#
#              Opponent Start       Pos   Min  ...   Cmp   Att  Cmp%  PrgP  \
# 52            Watford     N     CB,FW   2.0  ...   0.0   0.0   NaN   0.0
# ...

# %%
prem_mutiple_pos['Pos'] = prem_mutiple_pos['Pos'].str.split(',')
prem_mutiple_pos.explode('Pos')
# Out:
# C:\Users\salee\AppData\Local\Temp\ipykernel_42268\1531065824.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prem_mutiple_pos['Pos'] = prem_mutiple_pos['Pos'].str.split(',')
#              Date  Day         Round Venue Result            Squad  \
# 52     2018-12-04  Tue  Matchweek 15  Away  W 2–1  Manchester City
# 52     2018-12-04  Tue  Matchweek 15  Away  W 2–1  Manchester City
# 73     2018-08-12  Sun   Matchweek 1  Away  W 2–0  Manchester City
# 73     2018-08-12  Sun   Matchweek 1  Away  W 2–0  Manchester City
# 74     2018-08-19  Sun   Matchweek 2  Home  W 6–1  Manchester City
# ...           ...  ...           ...   ...    ...              ...
# 54249  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# ...

# %%
new_prem_players = prem_mutiple_pos.explode('Pos')

# %%
new_prem_players
# Out:
#              Date  Day         Round Venue Result            Squad  \
# 52     2018-12-04  Tue  Matchweek 15  Away  W 2–1  Manchester City
# 52     2018-12-04  Tue  Matchweek 15  Away  W 2–1  Manchester City
# 73     2018-08-12  Sun   Matchweek 1  Away  W 2–0  Manchester City
# 73     2018-08-12  Sun   Matchweek 1  Away  W 2–0  Manchester City
# 74     2018-08-19  Sun   Matchweek 2  Home  W 6–1  Manchester City
# ...           ...  ...           ...   ...    ...              ...
# 54249  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54275  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54275  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54277  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54277  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
#
#            Opponent Start Pos   Min  ...   Cmp   Att  Cmp%  PrgP  Carries  \
# 52          Watford     N  CB   2.0  ...   0.0   0.0   NaN   0.0      0.0
# ...

# %%
prem_single_pos = prem_player[prem_player['Pos'].str.len() ==2]

# %%
prem_single_pos
# Out:
#              Date  Day         Round Venue Result            Squad  \
# 0      2018-08-12  Sun   Matchweek 1  Away  W 2–0  Manchester City
# 1      2018-08-19  Sun   Matchweek 2  Home  W 6–1  Manchester City
# 2      2018-08-25  Sat   Matchweek 3  Away  D 1–1  Manchester City
# 3      2018-09-01  Sat   Matchweek 4  Home  W 2–1  Manchester City
# 4      2018-09-15  Sat   Matchweek 5  Home  W 3–0  Manchester City
# ...           ...  ...           ...   ...    ...              ...
# 54276  2023-05-21  Sun  Matchweek 37  Away  L 1–3      Southampton
# 54278  2023-05-21  Sun  Matchweek 37  Away  L 1–3      Southampton
# 54279  2023-01-21  Sat  Matchweek 21  Home  L 0–1      Southampton
# 54280  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54281  2022-08-06  Sat   Matchweek 1  Away  L 1–4      Southampton
#
#             Opponent Start Pos   Min  ...   Cmp   Att   Cmp%  PrgP  Carries  \
# 0            Arsenal     Y  GK  90.0  ...  33.0  46.0   71.7   0.0     27.0
# ...

# %%
fixed_players = pd.concat([prem_single_pos, new_prem_players])

# %%
fixed_players
# Out:
#              Date  Day         Round Venue Result            Squad  \
# 0      2018-08-12  Sun   Matchweek 1  Away  W 2–0  Manchester City
# 1      2018-08-19  Sun   Matchweek 2  Home  W 6–1  Manchester City
# 2      2018-08-25  Sat   Matchweek 3  Away  D 1–1  Manchester City
# 3      2018-09-01  Sat   Matchweek 4  Home  W 2–1  Manchester City
# 4      2018-09-15  Sat   Matchweek 5  Home  W 3–0  Manchester City
# ...           ...  ...           ...   ...    ...              ...
# 54249  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54275  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54275  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54277  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54277  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
#
#             Opponent Start Pos   Min  ...   Cmp   Att   Cmp%  PrgP  Carries  \
# 0            Arsenal     Y  GK  90.0  ...  33.0  46.0   71.7   0.0     27.0
# ...

# %%
fixed_players[fixed_players['Pos'].str.len() ==2]
# Out:
#              Date  Day         Round Venue Result            Squad  \
# 0      2018-08-12  Sun   Matchweek 1  Away  W 2–0  Manchester City
# 1      2018-08-19  Sun   Matchweek 2  Home  W 6–1  Manchester City
# 2      2018-08-25  Sat   Matchweek 3  Away  D 1–1  Manchester City
# 3      2018-09-01  Sat   Matchweek 4  Home  W 2–1  Manchester City
# 4      2018-09-15  Sat   Matchweek 5  Home  W 3–0  Manchester City
# ...           ...  ...           ...   ...    ...              ...
# 54249  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54275  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54275  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54277  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
# 54277  2023-05-28  Sun  Matchweek 38  Home  D 4–4      Southampton
#
#             Opponent Start Pos   Min  ...   Cmp   Att   Cmp%  PrgP  Carries  \
# 0            Arsenal     Y  GK  90.0  ...  33.0  46.0   71.7   0.0     27.0
# ...

# %%
grouped = df.groupby('PlayerName')
average_stats = grouped.mean()
